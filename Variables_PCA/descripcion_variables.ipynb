# %%
import pandas as pd

# %%
variables = pd.read_csv('variables_pca.csv')

# %%
variables1 = variables.drop(['longitude', 'latitude'], axis = 1)

# %%
variables_group = variables1.groupby(['cluster'])

# %%
tabla_resumen = variables_group.describe()

# %%
tabla_resumen = tabla_resumen.T

# %%
tabla_resumen.columns
# Out:
# Int64Index([-1, 0, 1, 2, 3, 4], dtype='int64', name='cluster')

# %%
tabla_resumen = round(tabla_resumen.rename({-1:1,0:2,1:3,2:4,3:5,4:6}, axis=1),2)

# %%
tabla_resumen
# Out:
# cluster                          5         6       5       6       5       6
# edad                 count    1.00  20656.00   88.00   35.00   18.00    7.00
#                      mean     6.60      7.03    6.67    6.65    6.63    7.63
#                      std       NaN      0.85    0.48    0.26    0.38    0.77
#                      min      6.60      0.91    5.20    5.90    6.20    7.00
#                      25%      6.60      6.50    6.60    6.50    6.20    7.00
#                      50%      6.60      7.00    6.70    6.60    6.85    7.50
#                      75%      6.60      7.40    6.80    6.90    7.00    8.10
#                      max      6.60     14.40    7.70    7.00    7.00    8.71
# PRECTOTCORR          count    1.00  20656.00   88.00   35.00   18.00    7.00
#                      mean     0.22      4.18    5.63    2.90    4.10    4.15
#                      std       NaN      6.48    7.61    2.83    4.14    6.49
# ...
